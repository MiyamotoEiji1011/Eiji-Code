# %%
import cv2
from cv2 import aruco
import numpy as np
import serial
import time

def get_mark_coordinate(cap, dict_aruco, parameters, num_id):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    corners, ids, rejectedImgPoints = aruco.detectMarkers(gray, dict_aruco, parameters=parameters)

    if ids is not None and num_id in ids:
        index = np.where(ids == num_id)[0][0]
        cornerUL = corners[index][0][0]
        cornerUR = corners[index][0][1]
        cornerBR = corners[index][0][2]
        cornerBL = corners[index][0][3]

        center = [(cornerUL[0] + cornerBR[0]) / 2, (cornerUL[1] + cornerBR[1]) / 2]

        # Draw coordinates on the frame
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(frame, f'ID: {num_id}', (int(center[0]), int(center[1])), font, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
        cv2.putText(frame, f'Coord: ({center[0]:.2f}, {center[1]:.2f})', (10, 30), font, 0.5, (0, 0, 255), 1, cv2.LINE_AA)

        cv2.imshow('Camera Window', frame)

        return center

    # If ID is not found, display the original frame
    cv2.imshow('Camera Window', frame)

    return None

def send_command_and_wait(ser, cap, command, expected_response):
    cap.grab()
    while True:
        if command != "none":
            ser.write((command + '\n').encode())

        response = ser.readline().decode().strip()
        if response == expected_response:
            print("Arduino Response:", response)
            break

cameraID = 0
cap = cv2.VideoCapture(cameraID)
dict_aruco = aruco.getPredefinedDictionary(aruco.DICT_4X4_50)
parameters = aruco.DetectorParameters()

markID = 5

# Arduinoとのシリアル通信設定
arduino_port = 'COM4'  # Arduinoのポートに合わせて変更
arduino_baudrate = 115200
ser = serial.Serial(arduino_port, arduino_baudrate, timeout=1)

try:
    send_command_and_wait(ser, cap, 'serial_connecting', 'serial_connected')
    send_command_and_wait(ser, cap, 'motor_offset', 'processing_now')
    send_command_and_wait(ser, cap, 'none', 'processing_completed')
    time.sleep(2)

    send_command_and_wait(ser, cap, 'motorA_start', 'processing_now')

    # Rest of the code
    while True:
        date = get_mark_coordinate(cap, dict_aruco, parameters, markID)
        if date[1] < 180 +10:
            send_command_and_wait(ser, cap, 'motorA_stop', 'stop_motorA')
            send_command_and_wait(ser, cap, 'none', 'processing_completed')
            break

    
    send_command_and_wait(ser, cap, 'motorB_start', 'processing_now')

    # Rest of the code
    while True:
        date = get_mark_coordinate(cap, dict_aruco, parameters, markID)
        if date[0] < 350 +10:
            send_command_and_wait(ser, cap, 'motorB_stop', 'stop_motorB')
            send_command_and_wait(ser, cap, 'none', 'processing_completed')
            break

except Exception as e:
    print("Error:", str(e))


time.sleep(1)

print(' ----- get_mark_coordinate ----- ')
print(get_mark_coordinate(cap, dict_aruco, parameters, markID))

send_command_and_wait(ser, cap, 'process_end', 'end_return')
print('------process end------')

ser.close()
cap.release()

cv2.destroyAllWindows()
# Out:
# Python Response: [280.5, 208.5]
# Arduino Response: Received Data: X = 280.50, Y = 208.50
# Python Response: [280.5, 208.5]
# Arduino Response: Received Data: X = 280.50, Y = 208.50
# Python Response: [280.5, 208.5]
# Arduino Response: Received Data: X = 280.50, Y = 208.50
# Python Response: [280.5, 208.5]
# Arduino Response: Received Data: X = 280.50, Y = 208.50
# Python Response: [280.5, 208.5]
# Arduino Response: Received Data: X = 280.50, Y = 208.50
# Python Response: [280.5, 208.5]
# Arduino Response: Received Data: X = 280.50, Y = 208.50
# Python Response: [280.5, 208.5]
# Arduino Response: Received Data: X = 280.50, Y = 208.50
# Python Response: [280.5, 208.5]
# Arduino Response: Received Data: X = 280.50, Y = 208.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.5, 209.5]
# Arduino Response: Received Data: X = 280.50, Y = 209.50
# Python Response: [280.0, 210.0]
# Arduino Response: Received Data: X = 280.00, Y = 210.00
# Python Response: [280.5, 210.0]
# Arduino Response: Received Data: X = 280.50, Y = 210.00
# Python Response: [280.5, 211.0]
# Arduino Response: Received Data: X = 280.50, Y = 211.00
# Python Response: [280.0, 211.5]
# Arduino Response: Received Data: X = 280.00, Y = 211.50
# Python Response: [280.0, 212.0]
# Arduino Response: Received Data: X = 280.00, Y = 212.00
# Python Response: [280.0, 212.0]
# Arduino Response: Received Data: X = 280.00, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [281.0, 212.0]
# Arduino Response: Received Data: X = 281.00, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [281.5, 211.0]
# Arduino Response: Received Data: X = 281.50, Y = 211.00
# Python Response: [281.5, 211.5]
# Arduino Response: Received Data: X = 281.50, Y = 211.50
# Python Response: [281.0, 212.0]
# Arduino Response: Received Data: X = 281.00, Y = 212.00
# Python Response: [281.5, 212.0]
# Arduino Response: Received Data: X = 281.50, Y = 212.00
# Python Response: [281.5, 212.0]
# Arduino Response: Received Data: X = 281.50, Y = 212.00
# Python Response: [281.5, 212.0]
# Arduino Response: Received Data: X = 281.50, Y = 212.00
# Python Response: [281.5, 212.0]
# Arduino Response: Received Data: X = 281.50, Y = 212.00
# Python Response: [281.0, 212.0]
# Arduino Response: Received Data: X = 281.00, Y = 212.00
# Python Response: [281.5, 211.0]
# Arduino Response: Received Data: X = 281.50, Y = 211.00
# Python Response: [281.5, 211.5]
# Arduino Response: Received Data: X = 281.50, Y = 211.50
# Python Response: [281.5, 211.5]
# Arduino Response: Received Data: X = 281.50, Y = 211.50
# Python Response: [281.5, 211.0]
# Arduino Response: Received Data: X = 281.50, Y = 211.00
# Python Response: [281.5, 211.0]
# Arduino Response: Received Data: X = 281.50, Y = 211.00
# Python Response: [281.5, 211.0]
# Arduino Response: Received Data: X = 281.50, Y = 211.00
# Python Response: [281.0, 211.0]
# Arduino Response: Received Data: X = 281.00, Y = 211.00
# Python Response: [280.5, 210.0]
# Arduino Response: Received Data: X = 280.50, Y = 210.00
# Python Response: [280.5, 211.0]
# Arduino Response: Received Data: X = 280.50, Y = 211.00
# Python Response: [280.5, 210.5]
# Arduino Response: Received Data: X = 280.50, Y = 210.50
# Python Response: [281.0, 210.0]
# Arduino Response: Received Data: X = 281.00, Y = 210.00
# Python Response: [281.0, 210.0]
# Arduino Response: Received Data: X = 281.00, Y = 210.00
# Python Response: [281.0, 209.5]
# Arduino Response: Received Data: X = 281.00, Y = 209.50
# Python Response: [281.0, 209.5]
# Arduino Response: Received Data: X = 281.00, Y = 209.50
# Python Response: [281.5, 210.0]
# Arduino Response: Received Data: X = 281.50, Y = 210.00
# Python Response: [281.0, 211.0]
# Arduino Response: Received Data: X = 281.00, Y = 211.00
# Python Response: [281.0, 211.5]
# Arduino Response: Received Data: X = 281.00, Y = 211.50
# Python Response: [281.5, 212.0]
# Arduino Response: Received Data: X = 281.50, Y = 212.00
# Python Response: [281.0, 212.0]
# Arduino Response: Received Data: X = 281.00, Y = 212.00
# Python Response: [281.0, 212.0]
# Arduino Response: Received Data: X = 281.00, Y = 212.00
# Python Response: [281.0, 212.0]
# Arduino Response: Received Data: X = 281.00, Y = 212.00
# Python Response: [281.0, 212.0]
# Arduino Response: Received Data: X = 281.00, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [281.0, 211.0]
# Arduino Response: Received Data: X = 281.00, Y = 211.00
# Python Response: [281.0, 211.0]
# Arduino Response: Received Data: X = 281.00, Y = 211.00
# Python Response: [281.5, 211.0]
# Arduino Response: Received Data: X = 281.50, Y = 211.00
# Python Response: [281.0, 211.5]
# Arduino Response: Received Data: X = 281.00, Y = 211.50
# Python Response: [281.0, 211.5]
# Arduino Response: Received Data: X = 281.00, Y = 211.50
# Python Response: [281.0, 212.0]
# Arduino Response: Received Data: X = 281.00, Y = 212.00
# Python Response: [281.0, 213.0]
# Arduino Response: Received Data: X = 281.00, Y = 213.00
# Python Response: [281.5, 212.5]
# Arduino Response: Received Data: X = 281.50, Y = 212.50
# Python Response: [281.5, 212.0]
# Arduino Response: Received Data: X = 281.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [281.0, 212.0]
# Arduino Response: Received Data: X = 281.00, Y = 212.00
# Python Response: [280.5, 212.0]
# Arduino Response: Received Data: X = 280.50, Y = 212.00
# Python Response: [280.5, 211.0]
# Arduino Response: Received Data: X = 280.50, Y = 211.00
# Python Response: [281.5, 210.5]
# Arduino Response: Received Data: X = 281.50, Y = 210.50
# Python Response: [281.0, 210.0]
# Arduino Response: Received Data: X = 281.00, Y = 210.00
# Python Response: [281.0, 209.5]
# Arduino Response: Received Data: X = 281.00, Y = 209.50
# Python Response: [281.0, 209.5]
# Arduino Response: Received Data: X = 281.00, Y = 209.50
# Python Response: [281.0, 209.5]
# Arduino Response: Received Data: X = 281.00, Y = 209.50
# Python Response: [281.0, 210.0]
# Arduino Response: Received Data: X = 281.00, Y = 210.00
# Python Response: [281.0, 210.0]
# Arduino Response: Received Data: X = 281.00, Y = 210.00
# Python Response: [281.5, 209.5]
# Arduino Response: Received Data: X = 281.50, Y = 209.50
# Python Response: [281.0, 209.5]
# Arduino Response: Received Data: X = 281.00, Y = 209.50
# Python Response: [281.0, 209.5]
# Arduino Response: Received Data: X = 281.00, Y = 209.50
# Python Response: [281.5, 209.0]
# Arduino Response: Received Data: X = 281.50, Y = 209.00
# Python Response: [281.5, 206.0]
# Arduino Response: Received Data: X = 281.50, Y = 206.00
# Python Response: [281.5, 206.0]
# Arduino Response: Received Data: X = 281.50, Y = 206.00
# Python Response: [281.5, 206.0]
# Arduino Response: Received Data: X = 281.50, Y = 206.00
# Python Response: [281.5, 206.0]
# Arduino Response: Received Data: X = 281.50, Y = 206.00
# Python Response: [282.0, 205.5]
# Arduino Response: Received Data: X = 282.00, Y = 205.50
# Python Response: [281.5, 206.5]
# Arduino Response: Received Data: X = 281.50, Y = 206.50
# Python Response: [281.0, 207.0]
# Arduino Response: Received Data: X = 281.00, Y = 207.00
# Python Response: [281.5, 206.5]
# Arduino Response: Received Data: X = 281.50, Y = 206.50
# Python Response: [281.5, 206.0]
# Arduino Response: Received Data: X = 281.50, Y = 206.00
# Python Response: [282.0, 206.0]
# Arduino Response: Received Data: X = 282.00, Y = 206.00
# Python Response: [281.5, 207.0]
# Arduino Response: Received Data: X = 281.50, Y = 207.00
# Python Response: [281.0, 209.0]
# Arduino Response: Received Data: X = 281.00, Y = 209.00
# Python Response: [281.5, 210.5]
# Arduino Response: Received Data: X = 281.50, Y = 210.50
# Python Response: [282.0, 216.0]
# Arduino Response: Received Data: X = 282.00, Y = 216.00
# Python Response: [282.0, 223.5]
# Arduino Response: Received Data: X = 282.00, Y = 223.50
# Python Response: [282.5, 225.0]
# Arduino Response: Received Data: X = 282.50, Y = 225.00
# Python Response: [283.0, 225.5]
# Arduino Response: Received Data: X = 283.00, Y = 225.50
# Python Response: [283.0, 225.0]
# Arduino Response: Received Data: X = 283.00, Y = 225.00
# Python Response: [282.5, 224.5]
# Arduino Response: Received Data: X = 282.50, Y = 224.50
# Python Response: [282.0, 222.5]
# Arduino Response: Received Data: X = 282.00, Y = 222.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 211.5]
# Arduino Response: Received Data: X = 282.00, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.5, 211.5]
# Arduino Response: Received Data: X = 282.50, Y = 211.50
# Python Response: [282.0, 213.0]
# Arduino Response: Received Data: X = 282.00, Y = 213.00
# Python Response: [282.0, 216.0]
# Arduino Response: Received Data: X = 282.00, Y = 216.00
# Python Response: [282.0, 220.0]
# Arduino Response: Received Data: X = 282.00, Y = 220.00
# Python Response: [282.0, 223.5]
# Arduino Response: Received Data: X = 282.00, Y = 223.50
# Python Response: [282.0, 230.0]
# Arduino Response: Received Data: X = 282.00, Y = 230.00
# Python Response: [282.0, 236.0]
# Arduino Response: Received Data: X = 282.00, Y = 236.00
# Python Response: [282.0, 242.0]
# Arduino Response: Received Data: X = 282.00, Y = 242.00
# Python Response: [282.0, 247.5]
# Arduino Response: Received Data: X = 282.00, Y = 247.50
# Python Response: [281.5, 252.0]
# Arduino Response: Received Data: X = 281.50, Y = 252.00
# Python Response: [281.5, 259.0]
# Arduino Response: Received Data: X = 281.50, Y = 259.00
# Python Response: [281.5, 263.5]
# Arduino Response: Received Data: X = 281.50, Y = 263.50
# Python Response: [281.5, 269.5]
# Arduino Response: Received Data: X = 281.50, Y = 269.50
# Python Response: [281.0, 275.0]
# Arduino Response: Received Data: X = 281.00, Y = 275.00
# Python Response: [281.5, 279.0]
# Arduino Response: Received Data: X = 281.50, Y = 279.00
# Python Response: [281.5, 279.0]
# Arduino Response: Received Data: X = 281.50, Y = 279.00
# Python Response: [281.5, 287.5]
# Arduino Response: Received Data: X = 281.50, Y = 287.50
# Python Response: [281.0, 290.5]
# Arduino Response: Received Data: X = 281.00, Y = 290.50
# Python Response: [281.0, 293.5]
# Arduino Response: Received Data: X = 281.00, Y = 293.50
# Python Response: [280.5, 296.5]
# Arduino Response: Received Data: X = 280.50, Y = 296.50
# Python Response: [280.5, 299.5]
# Arduino Response: Received Data: X = 280.50, Y = 299.50
# Python Response: [280.5, 303.0]
# Arduino Response: Received Data: X = 280.50, Y = 303.00
# Python Response: [280.5, 304.0]
# Arduino Response: Received Data: X = 280.50, Y = 304.00
# Python Response: [280.5, 307.5]
# Arduino Response: Received Data: X = 280.50, Y = 307.50
# Python Response: [280.5, 307.5]
# Arduino Response: Received Data: X = 280.50, Y = 307.50
# Python Response: [280.5, 309.5]
# Arduino Response: Received Data: X = 280.50, Y = 309.50
# Python Response: [280.5, 312.0]
# Arduino Response: Received Data: X = 280.50, Y = 312.00
# Python Response: [280.5, 314.0]
# Arduino Response: Received Data: X = 280.50, Y = 314.00
# Python Response: [280.5, 316.5]
# Arduino Response: Received Data: X = 280.50, Y = 316.50
# Python Response: [280.5, 318.0]
# Arduino Response: Received Data: X = 280.50, Y = 318.00
# Python Response: [280.5, 317.0]
# Arduino Response: Received Data: X = 280.50, Y = 317.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.5]
# Arduino Response: Received Data: X = 280.50, Y = 319.50
# Python Response: [280.5, 320.0]
# Arduino Response: Received Data: X = 280.50, Y = 320.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 318.0]
# Arduino Response: Received Data: X = 280.50, Y = 318.00
# Python Response: [280.5, 319.5]
# Arduino Response: Received Data: X = 280.50, Y = 319.50
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.5]
# Arduino Response: Received Data: X = 280.50, Y = 319.50
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.5]
# Arduino Response: Received Data: X = 280.50, Y = 319.50
# Python Response: [280.0, 318.0]
# Arduino Response: Received Data: X = 280.00, Y = 318.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# ...
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.0, 318.0]
# Arduino Response: Received Data: X = 280.00, Y = 318.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 318.0]
# Arduino Response: Received Data: X = 280.50, Y = 318.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00
# Python Response: [280.5, 319.0]
# Arduino Response: Received Data: X = 280.50, Y = 319.00

# %%
import cv2
from cv2 import aruco
import numpy as np
import serial
import time
import mediapipe as mp

def get_index_finger_tip_coordinates(cap):
    while True:
        ret, frame = cap.read()
        results = hands.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

        if results.multi_hand_landmarks:
            hand_landmarks = results.multi_hand_landmarks[0]  # Assuming only one hand is detected
            index_finger_tip = hand_landmarks.landmark[8]
            height, width, _ = frame.shape

            # 座標変換: 中心を原点とする座標系に変換
            x_pixel = int(index_finger_tip.x * width - width / 2)
            y_pixel = int(index_finger_tip.y * height - height / 2)

            return x_pixel, y_pixel



def send_command_and_wait(ser, cap, command, expected_response):
    cap.grab()
    while True:
        if command != "none":
            ser.write((command + '\n').encode())

        response = ser.readline().decode().strip()
        if response == expected_response:
            print("Arduino Response:", response)
            break

def get_mark_coordinate(cap, dict_aruco, parameters, num_id):
    while True:
        ret, frame = cap.read()
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        corners, ids, rejectedImgPoints = aruco.detectMarkers(gray, dict_aruco, parameters=parameters)

        if ids is not None and num_id in ids:
            index = np.where(ids == num_id)[0][0]
            cornerUL = corners[index][0][0]
            cornerUR = corners[index][0][1]
            cornerBR = corners[index][0][2]
            cornerBL = corners[index][0][3]

            center = [(cornerUL[0] + cornerBR[0]) / 2, (cornerUL[1] + cornerBR[1]) / 2]

            # Draw coordinates on the frame
            font = cv2.FONT_HERSHEY_SIMPLEX
            
            # Get the image center coordinates
            height, width, _ = frame.shape
            image_center = (width // 2, height // 2)

            # Convert coordinates to center-based coordinate system
            center_based_coords = (int(center[0]) - image_center[0], int(center[1]) - image_center[1])

            return center_based_coords



hands = mp.solutions.hands.Hands(
    max_num_hands=1,
    min_detection_confidence=0.5)

cameraID = 0
cap = cv2.VideoCapture(cameraID)
dict_aruco = aruco.getPredefinedDictionary(aruco.DICT_4X4_50)
parameters = aruco.DetectorParameters()

markID = 5

# Arduinoとのシリアル通信設定
arduino_port = 'COM4'  # Arduinoのポートに合わせて変更
arduino_baudrate = 115200
ser = serial.Serial(arduino_port, arduino_baudrate, timeout=1)

timeout_seconds = 5  # 30秒のタイムアウトを設定

try:
    send_command_and_wait(ser, cap, 'serial_connecting', 'serial_connected')
    send_command_and_wait(ser, cap, 'motor_offset', 'processing_now')
    send_command_and_wait(ser, cap, 'none', 'processing_completed')
    time.sleep(2)
    ###key press

    coordinates = get_index_finger_tip_coordinates(cap)
    x_pixel, y_pixel = coordinates

    if coordinates:

        if 160 < x_pixel < -130 and 160 < y_pixel < 130:
            # マーカー位置の取得
            marker_position = get_mark_coordinate(cap, dict_aruco, parameters, markID)
            if marker_position:
                print(f"Index Finger Tip: ({x_pixel}, {y_pixel})")
                print(f"ArUco Marker Position: {marker_position}")
        print(f"Index Finger Tip: ({x_pixel}, {y_pixel})")

    
    send_command_and_wait(ser, cap, 'motorB_start', 'processing_now')

    # Rest of the code
    start_time = time.time()
    while True:
        date = get_mark_coordinate(cap, dict_aruco, parameters, markID)
        if date[0] <= x_pixel + 30:
            send_command_and_wait(ser, cap, 'motorB_stop', 'stop_motorB')
            send_command_and_wait(ser, cap, 'none', 'processing_completed')
            break

        if time.time() - start_time > timeout_seconds:
            print("Timeout reached. Exiting the loop.")
            break


    send_command_and_wait(ser, cap, 'motorA_start', 'processing_now')

    # Rest of the code
    start_time = time.time()
    while True:
        date = get_mark_coordinate(cap, dict_aruco, parameters, markID)
        if date[1] <= y_pixel + 190:
            send_command_and_wait(ser, cap, 'motorA_stop', 'stop_motorA')
            send_command_and_wait(ser, cap, 'none', 'processing_completed')
            break
        if time.time() - start_time > timeout_seconds:
            print("Timeout reached. Exiting the loop.")
            break

    send_command_and_wait(ser, cap, 'servo_start', 'processing_now')
    send_command_and_wait(ser, cap, 'none', 'processing_completed')

except Exception as e:
    print("Error:", str(e))


time.sleep(1)

print(' ----- get_mark_coordinate ----- ')
print(get_mark_coordinate(cap, dict_aruco, parameters, markID))

send_command_and_wait(ser, cap, 'process_end', 'end_return')
print('------process end------')

ser.close()
cap.release()

cv2.destroyAllWindows()
# Out:
# Arduino Response: serial_connected
# Arduino Response: processing_now
# Arduino Response: processing_completed
# Index Finger Tip: (2, -102)
# Arduino Response: processing_now
# Arduino Response: stop_motorB
# Arduino Response: processing_completed
# Arduino Response: processing_now
# Arduino Response: stop_motorA
# Arduino Response: processing_completed
# Arduino Response: processing_now
# Arduino Response: processing_completed
#  ----- get_mark_coordinate -----
# (11, 69)
# Arduino Response: end_return
# ------process end------
